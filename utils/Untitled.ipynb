# %%
from Firehouse_dataset import Firehouse_dataset

# %%
from augmentations import *
dataset = Firehouse_dataset(root = "../" ,dataset_type = 'YOLO', smokeAugmentation = True , transform = SSDAugmentation())

# %%
img, labels , semi = dataset.__getitem__(0)
# Out:
# C:\Users\방재연\firehouse_test\fire_house\utils\augmentations.py:238: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)

# %%
import matplotlib.pyplot as plt

plt.imshow(img.permute(1,2,0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
labels
# Out:
# tensor([[0.0000, 3.0000, 0.8802, 0.7125, 0.2396, 0.5694],
#         [0.0000, 3.0000, 0.5521, 0.7694, 0.2208, 0.4500],
#         [0.0000, 3.0000, 0.5500, 0.5208, 0.1375, 0.2139],
#         [0.0000, 1.0000, 0.4979, 0.6181, 0.7000, 0.6972]])

# %%
img.permute(1,2,0).shape
# Out:
# torch.Size([300, 300, 3])

# %%
dataset.root
# Out:
# '../'

# %%
dataset.annopath_dir
# Out:
# '../data/fire/annotations/'
